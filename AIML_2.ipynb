# %% [markdown]
# <a href="https://colab.research.google.com/github/manthojunagachaitanya/23CSBTB39-40/blob/main/AIML_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from queue import Queue
graph ={0:[1,2,3],
        1:[0,2],
        2:[1,3,5],
        3:[0,2,4],
        4:[3,5,7],
        5:[2,4,6,7],
        6:[5,7],
        7:[],
        }
print("The adjacency list representing the graph is :")
print(graph)
# Out:
# The adjacency list representing the graph is :
# {0: [1, 2, 3], 1: [0, 2], 2: [1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [2, 4, 6, 7], 6: [5, 7], 7: []}

# %% [markdown]
# ![n.png](data:image/png;base64,...)
